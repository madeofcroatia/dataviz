# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Data comes in all sizes and shapes and formats, and we will spend lots of our time <b>wrangling</b> the data into the format we could use. Wrangling is a topic for another day; for now all data sets will be tidy right away.
#
# <h2>The data set</h2>
#
# The data file is a <b>CSV file</b>(comma-separated value). It is a text file that is easily read into data structures in many programming languages. When storing data, we should try to always store it in such a format which is open, has a well-defined specification, and is readable in many contexts.
# <ul>
#     <li><b>Good formats: </b> JSON, CSV</li>
#     <li><b>Bad formats: </b> Excel, <code>.mat</code></li>
# </ul>

# %%
# !head ../data/gfmt_sleep.csv #taking a peek!
# Out:
# ﻿participant number,gender,age,correct hit percentage,correct reject percentage,percent correct,confidence when correct hit,confidence incorrect hit,confidence correct reject,confidence incorrect reject,confidence when correct,confidence when incorrect,sci,psqi,ess
# 8,f,39,65,80,72.5,91,90,93,83.5,93,90,9,13,2
# 16,m,42,90,90,90,75.5,55.5,70.5,50,75,50,4,11,7
# 18,f,31,90,95,92.5,89.5,90,86,81,89,88,10,9,3
# 22,f,35,100,75,87.5,89.5,*,71,80,88,80,13,8,20
# 27,f,74,60,65,62.5,68.5,49,61,49,65,49,13,9,12
# 28,f,61,80,20,50,71,63,31,72.5,64.5,70.5,15,14,2
# 30,m,32,90,75,82.5,67,56.5,66,65,66,64,16,9,3
# 33,m,62,45,90,67.5,54,37,65,81.5,62,61,14,9,9
# 34,f,33,80,100,90,70.5,76.5,64.5,*,68,76.5,14,12,10

# %% [markdown]
# While we could write a parser for this file, since it is in a CSV format we could use pre-built tools. For this we may use <b>Pandas</b>, a <b>powerful</b> tool for handling data.
# <h2>Pandas</h2>
# The primary object of Pandas is the <code>DataFrame</code>. We will use Pandas to read data and store it into <code>DataFrame</code> instance.

# %%
df = pd.read_csv('../data/gfmt_sleep.csv', na_values='*')

# %%
# Look at the contents of first 5 rows:
df.head()
# Out:
#    participant number gender  age  correct hit percentage  \
# 0                   8      f   39                      65
# 1                  16      m   42                      90
# 2                  18      f   31                      90
# 3                  22      f   35                     100
# 4                  27      f   74                      60
#
#    correct reject percentage  percent correct  confidence when correct hit  \
# 0                         80             72.5                         91.0
# 1                         90             90.0                         75.5
# 2                         95             92.5                         89.5
# 3                         75             87.5                         89.5
# 4                         65             62.5                         68.5
#
#    confidence incorrect hit  confidence correct reject  \
# 0                      90.0                       93.0
# ...

# %% [markdown]
# <code>DataFrame</code> is always indexed by columns, with column names(<code>string</code> values) being the keys.

# %%
df['percent correct'].head()
# Out:
# 0    72.5
# 1    90.0
# 2    92.5
# 3    87.5
# 4    62.5
# Name: percent correct, dtype: float64

# %% [markdown]
# To refer to a particular element of the column we can use integer indexes.

# %%
df['percent correct'][4]
# Out:
# 62.5

# %% [markdown]
# However, this is <b>not</b> the preferred way to do this. It is better to use <code>loc</code> method:

# %%
df.loc[4, 'percent correct']
# Out:
# 62.5

# %% [markdown]
# <b>Row indices need not be integers</b>, and we should not count on that. In practice, almost always we will use <b>boolean indexing</b>.

# %%
# Get the value(s) in the column 'percent correct' with the value in 'participant number' 42
df.loc[df['participant number'] == 42, 'percent correct']
# Out:
# 54    85.0
# Name: percent correct, dtype: float64

# %%
# Get the entire row about participant with number 42
df.loc[df['participant number'] == 42, :]
# Out:
#     participant number gender  age  correct hit percentage  \
# 54                  42      m   29                     100
#
#     correct reject percentage  percent correct  confidence when correct hit  \
# 54                         70             85.0                         75.0
#
#     confidence incorrect hit  confidence correct reject  \
# 54                       NaN                       64.5
#
#     confidence incorrect reject  confidence when correct  \
# 54                         43.0                     74.0
#
#     confidence when incorrect  sci  psqi  ess
# 54                       43.0   32     1    6

# %% [markdown]
# We can use boolean bitwise operators in the boolean indexing. <code>&</code> for bitwise AND, <code>|</code> for bitwise OR, <code>~</code> for bitwise NOT.

# %%
# Get entries for women under 21
df.loc[(df['age'] < 21) & (df['gender'] == 'f'), :]
# Out:
#     participant number gender  age  correct hit percentage  \
# 27                   3      f   16                      70
# 29                   5      f   18                      90
# 66                  58      f   16                      85
# 79                  72      f   18                      80
# 88                  85      f   18                      85
#
#     correct reject percentage  percent correct  confidence when correct hit  \
# 27                         80             75.0                         70.0
# 29                        100             95.0                         76.5
# 66                         85             85.0                         55.0
# 79                         75             77.5                         67.5
# 88                         85             85.0                         93.0
#
#     confidence incorrect hit  confidence correct reject  \
# 27                      57.0                       54.0
# ...

# %%
# We create three boolean arrays, and for each the entries are True if and only if the
# Boolean statement evaluated at the identical cell at the expression on the right is True
# and False otherwise

under30 = df['age'] < 30
women = df['gender'] == 'f'
good_performers = df['percent correct'] > 85

# %%
# Get the entries of Women under 30 who performed good on the face matching test
df.loc[under30 & women & good_performers, :]
# Out:
#     participant number gender  age  correct hit percentage  \
# 22                  93      f   28                     100
# 29                   5      f   18                      90
# 30                   6      f   28                      95
# 33                  10      f   25                     100
# 56                  44      f   21                      85
# 58                  48      f   23                      90
# 60                  51      f   24                      85
# 75                  67      f   25                     100
#
#     correct reject percentage  percent correct  confidence when correct hit  \
# 22                         75             87.5                         89.5
# 29                        100             95.0                         76.5
# 30                         80             87.5                        100.0
# 33                        100            100.0                         90.0
# ...

# %% [markdown]
# This would normally require us to use loops, but the numpy and pandas libraries allow us to treat all this as simple non-loop operations.

# %%
# initialize the list of Boolean indices
indices = [False] * len(df)

# Iterate over the rows of the DataFrame to check if the row should be included
for i, r in df.iterrows():
    if r['age'] < 30 and r['gender'] == 'f' and r['percent correct'] > 85:
        indices[i] = True

#Make our selection with Boolean indexing
df.loc[indices, :]
# Out:
#     participant number gender  age  correct hit percentage  \
# 22                  93      f   28                     100
# 29                   5      f   18                      90
# 30                   6      f   28                      95
# 33                  10      f   25                     100
# 56                  44      f   21                      85
# 58                  48      f   23                      90
# 60                  51      f   24                      85
# 75                  67      f   25                     100
#
#     correct reject percentage  percent correct  confidence when correct hit  \
# 22                         75             87.5                         89.5
# 29                        100             95.0                         76.5
# 30                         80             87.5                        100.0
# 33                        100            100.0                         90.0
# ...

# %% [markdown]
# <code>df.iterrows()</code> creates an iterator over the rows of the <code>DataFrame</code>. As we can see, <code>DataFrame</code> is a powerful tool that allows us to do all that looping without worrying about the implementation, while keeping the readability to maximum. The iterator itself is rarely used, but there may be cases when it is needed. As we will see now, most of the times we can just do calculations on <code>DataFrame</code> directly.

# %% [markdown]
# <h2>Calculating with data frames</h2>
# Test subject is said to have insomnia if they have an SCI of 16 at most. We might want to add a column that explicitly says if the subject has insomnia.

# %%
(df['sci'] <= 16) # --- Create a boolean column that is true if and only if the subject for
                  #     whom the row corresponds has insomnia.
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 97     False
# 98     False
# 99     False
# 100    False
# 101    False
# Name: sci, Length: 102, dtype: bool

# %%
# Create a column with the name "insomnia" which is the Boolean column cell of which are 
# True if and only if the SCI of the subject is at most 16, and False otherwise.
df['insomnia'] = df['sci'] <= 16

# Taking a peek!
df.head()
# Out:
#    participant number gender  age  correct hit percentage  \
# 0                   8      f   39                      65
# 1                  16      m   42                      90
# 2                  18      f   31                      90
# 3                  22      f   35                     100
# 4                  27      f   74                      60
#
#    correct reject percentage  percent correct  confidence when correct hit  \
# 0                         80             72.5                         91.0
# 1                         90             90.0                         75.5
# 2                         95             92.5                         89.5
# 3                         75             87.5                         89.5
# 4                         65             62.5                         68.5
#
#    confidence incorrect hit  confidence correct reject  \
# 0                      90.0                       93.0
# ...

# %% [markdown]
# Applying <code><=</code> operator to a <code>Series</code> resulted in <b>elementwise</b> application. This is called <strong>vectorization</strong>. Just like with numpy arrays, we can apply numpy functions to Pandas objects:

# %%
print('Insomniacs:', np.mean(df.loc[df['insomnia'], 'percent correct']))
print('Control:', np.mean(df.loc[~df['insomnia'], 'percent correct']))
# Out:
# Insomniacs: 76.1
# Control: 81.46103896103897

# %%
# DataFrame.describe method computes for us all the summary statistics we usually need
# for each column
df.describe()
# Out:
#        participant number         age  correct hit percentage  \
# count          102.000000  102.000000              102.000000
# mean            52.049020   37.921569               83.088235
# std             30.020909   14.029450               15.091210
# min              1.000000   16.000000               35.000000
# 25%             26.250000   26.500000               75.000000
# 50%             52.500000   36.500000               90.000000
# 75%             77.750000   45.000000               95.000000
# max            103.000000   74.000000              100.000000
#
#        correct reject percentage  percent correct  \
# count                 102.000000       102.000000
# mean                   77.205882        80.147059
# std                    17.569854        12.047881
# min                    20.000000        40.000000
# 25%                    70.000000        72.500000
# 50%                    80.000000        83.750000
# 75%                    90.000000        87.500000
# ...

# %% [markdown]
# <code>describe</code> is also a Pandas <code>DataFrame</code>, so we can use indexing, everything we did with <code>DataFrame</code>'s so far on it:

# %%
# Get the median for every column in df
df.describe().loc['50%', :]
# Out:
# participant number             52.50
# age                            36.50
# correct hit percentage         90.00
# correct reject percentage      80.00
# percent correct                83.75
# confidence when correct hit    75.00
# confidence incorrect hit       56.25
# confidence correct reject      71.25
# confidence incorrect reject    61.00
# confidence when correct        75.75
# confidence when incorrect      61.50
# sci                            23.50
# psqi                            5.00
# ess                             7.00
# Name: 50%, dtype: float64

# %% [markdown]
# <h2>Slicing with iloc</h2>
#
# Let’s say we wanted to consider only the males in the study. We can slice them out and put them in a new data frame (actually a view into the existing data frame df) using Boolean indexing.

# %%
df_males = df.loc[df['gender'] == 'm', :]

df_males.head()
# Out:
#     participant number gender  age  correct hit percentage  \
# 1                   16      m   42                      90
# 6                   30      m   32                      90
# 7                   33      m   62                      45
# 18                  78      m   31                     100
# 19                  80      m   28                     100
#
#     correct reject percentage  percent correct  confidence when correct hit  \
# 1                          90             90.0                         75.5
# 6                          75             82.5                         67.0
# 7                          90             67.5                         54.0
# 18                         70             85.0                         92.0
# 19                         50             75.0                        100.0
#
#     confidence incorrect hit  confidence correct reject  \
# 1                       55.5                       70.5
# ...

# %% [markdown]
# Note that the numbers of rows are here from the original <code>df</code>, and not 1, 2, 3, 4, 5... This is actually not too bad, since the row indices need not be integers! There is however a way to index through rows and columns by integers:

# %%
# Accessing "third" row and "zeroth" column with iloc
df_males.iloc[3, 0]
# Out:
# 78

# %% [markdown]
# However, we may be relying here on the <code>DataFrame</code> being sorted in a particular order, which is never a good practice. So, in reality we should never need to use <code>iloc</code>. <strong>Only</strong> use it when the order is irrelevant.

# %% [markdown]
# <h2>Renaming columns</h2>
#
# Truth be told, sci, psqi, ess do not tell much us without knowing what these abbreviations stand for. <i>Explicit <b>is</b> better than Implicit</i>, so let us make these column names longer:

# %%
# We need to make a renaming dictionary:
rename_dict = {
    "ess": "Epworth Sleepiness Scale",
    "sci": "Sleep Condition Indicator",
    "psqi": "Pittsburgh Sleep Quality Index",
}

# Rename the columns by calling the renaming dictionary
df = df.rename(columns=rename_dict)

df.head()
# Out:
#    participant number gender  age  correct hit percentage  \
# 0                   8      f   39                      65
# 1                  16      m   42                      90
# 2                  18      f   31                      90
# 3                  22      f   35                     100
# 4                  27      f   74                      60
#
#    correct reject percentage  percent correct  confidence when correct hit  \
# 0                         80             72.5                         91.0
# 1                         90             90.0                         75.5
# 2                         95             92.5                         89.5
# 3                         75             87.5                         89.5
# 4                         65             62.5                         68.5
#
#    confidence incorrect hit  confidence correct reject  \
# 0                      90.0                       93.0
# ...

# %% [markdown]
# Boolean indexing comes with a payoff, as it is essentially building a boolean array and reverse dictionary look-up for every <code>True</code> value, while non-boolean indexing is just a constant operation.

# %%
print("Boolean indexing(slow):")
# %timeit df.loc[df['participant number'] == 42, 'percent correct']

print("\nDirect indexing(fast):")
# %timeit df.loc[54, 'percent correct']
# Out:
# Boolean indexing(slow):
# 59.2 µs ± 696 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
#
# Direct indexing(fast):
# 3.34 µs ± 32.9 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
